# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\DURVA\Downloads\archive (3)\2026 QS World University Rankings.csv")

# %%
df
# Out:
#      2026 Rank Previous Rank                             Institution Name  \
# 0            1             1  Massachusetts Institute of Technology (MIT)
# 1            2             2                      Imperial College London
# 2            3             6                          Stanford University
# 3            4             3                         University of Oxford
# 4            5             4                           Harvard University
# ...        ...           ...                                          ...
# 1496     1401+     1201-1400                   University of West Bohemia
# 1497     1401+     1201-1400                    Voronezh State University
# 1498     1401+           NaN                          Walailak University
# 1499     1401+     1201-1400                         Yamaguchi University
# 1500     1401+     1201-1400                          Youngsan University
#
#              Country/Territory    Region Size Focus Research  \
# ...

# %%
df.dtypes
# Out:
# 2026 Rank             object
# Previous Rank         object
# Institution Name      object
# Country/Territory     object
# Region                object
# Size                  object
# Focus                 object
# Research              object
# Status                object
# AR SCORE             float64
# AR RANK               object
# ER SCORE             float64
# ER RANK               object
# FSR SCORE            float64
# FSR RANK              object
# CPF SCORE            float64
# CPF RANK              object
# IFR SCORE            float64
# IFR RANK              object
# ISR SCORE            float64
# ISR RANK              object
# ISD SCORE            float64
# ISD RANK              object
# IRN SCORE            float64
# IRN RANK              object
# EO SCORE             float64
# EO RANK               object
# SUS SCORE            float64
# SUS RANK              object
# Overall SCORE         object
# dtype: object

# %%
df.describe()
# Out:
#           AR SCORE     ER SCORE    FSR SCORE    CPF SCORE    IFR SCORE  \
# count  1501.000000  1501.000000  1501.000000  1501.000000  1414.000000
# mean     25.785943    26.944237    33.950433    30.425516    36.305658
# std      24.500905    25.504494    28.440071    29.679882    35.252024
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       8.800000     8.500000    10.800000     6.000000     6.600000
# 50%      16.000000    16.500000    23.500000    18.000000    20.100000
# 75%      32.700000    37.500000    50.500000    49.700000    66.100000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#         ISR SCORE    ISD SCORE    IRN SCORE     EO SCORE    SUS SCORE
# count  1464.00000  1464.000000  1499.000000  1501.000000  1477.000000
# mean     33.32541    34.526981    53.356905    29.989674    51.254367
# std      32.75066    31.108600    28.920632    29.197573    21.266331
# ...

# %%
# dropping the rank columns because the score columns has the same thing
# score values are continuous numeric values
df.drop(columns=[
    "AR RANK","ER RANK","FSR RANK","CPF RANK",
    "IFR RANK","ISR RANK","ISD RANK","IRN RANK",
    "EO RANK","SUS RANK"
], inplace=True)

# %%
df.isnull().sum()
# Out:
# 2026 Rank              0
# Previous Rank        112
# Institution Name       0
# Country/Territory      0
# Region                 0
# Size                   1
# Focus                  0
# Research               1
# Status                47
# AR SCORE               0
# ER SCORE               0
# FSR SCORE              0
# CPF SCORE              0
# IFR SCORE             87
# ISR SCORE             37
# ISD SCORE             37
# IRN SCORE              2
# EO SCORE               0
# SUS SCORE             24
# Overall SCORE          0
# dtype: int64

# %%
# dropping columns which are not the primary decision factors for a student to choose a country.
# keeping features like academic quality and job prospects while dropping less useful rank-based details.
df.drop(columns=[
    "2026 Rank",
    "Previous Rank",
    "IFR SCORE","ISR SCORE","ISD SCORE","IRN SCORE","SUS SCORE",
    "Status","Institution Name",
    "Focus","Overall SCORE",
    "Size","FSR SCORE"], inplace=True)

# %%
df.isnull().sum()
# Out:
# Country/Territory    0
# Region               0
# Research             1
# AR SCORE             0
# ER SCORE             0
# CPF SCORE            0
# EO SCORE             0
# dtype: int64

# %%
df
# Out:
#              Country/Territory    Region Research  AR SCORE  ER SCORE  \
# 0     United States of America  Americas       VH     100.0     100.0
# 1               United Kingdom    Europe       VH      99.6     100.0
# 2     United States of America  Americas       VH     100.0     100.0
# 3               United Kingdom    Europe       VH     100.0     100.0
# 4     United States of America  Americas       VH     100.0     100.0
# ...                        ...       ...      ...       ...       ...
# 1496                   Czechia    Europe       VH       7.2       5.3
# 1497        Russian Federation    Europe       HI       5.7       4.7
# 1498                  Thailand      Asia       MD       8.3       2.7
# 1499                     Japan      Asia       HI       4.4       2.9
# 1500         Republic of Korea      Asia       MD       6.5      11.9
#
#       CPF SCORE  EO SCORE
# 0         100.0     100.0
# 1          95.0      95.9
# 2          99.7     100.0
# ...

# %%
obj_cols = df.select_dtypes(include='object').columns
for col in obj_cols:
    print(f"\n{col}:")
    print(df[col].value_counts(dropna=False))
# Out:
# Country/Territory:
# Country/Territory
# United States of America    192
# United Kingdom               90
# China (Mainland)             72
# India                        54
# Germany                      48
#                            ...
# Luxembourg                    1
# Ethiopia                      1
# Malta                         1
# Iceland                       1
# Libya                         1
# Name: count, Length: 106, dtype: int64
#
# Region:
# Region
# Asia        565
# Europe      487
# Americas    358
# Africa       47
# Oceania      44
# Name: count, dtype: int64
#
# Research:
# Research
# VH     1056
# HI      354
# MD       80
# LO       10
# NaN       1
# Name: count, dtype: int64

# %%
df[df["Research"].isna()]
# Out:
#                Country/Territory Region Research  AR SCORE  ER SCORE  \
# 1240  Iran (Islamic Republic of)   Asia      NaN       6.1       5.0
#
#       CPF SCORE  EO SCORE
# 1240        8.5      35.7

# %%
df["Research"].fillna("Unknown", inplace=True)

# %%
df.isnull().sum()
# Out:
# Country/Territory    0
# Region               0
# Research             0
# AR SCORE             0
# ER SCORE             0
# CPF SCORE            0
# EO SCORE             0
# dtype: int64

# %%
for col in df.columns:
    print(f"\n{col} ({df[col].nunique()})")
    print(df[col].unique())
# Out:
# Country/Territory (106)
# ['United States of America' 'United Kingdom' 'Switzerland' 'Singapore'
#  'Hong Kong SAR, China' 'China (Mainland)' 'Australia' 'Germany' 'Canada'
#  'France' 'Japan' 'Republic of Korea' 'Netherlands' 'Malaysia' 'Belgium'
#  'Taiwan' 'New Zealand' 'Saudi Arabia' 'Sweden' 'Ireland' 'Argentina'
#  'Italy' 'Denmark' 'Russian Federation' 'Brazil' 'Qatar' 'Finland' 'Chile'
#  'Norway' 'India' 'Mexico' 'South Africa' 'Austria' 'Spain' 'Kazakhstan'
#  'United Arab Emirates' 'Indonesia' 'Colombia' 'Thailand' 'Israel'
#  'Portugal' 'Lebanon' 'Czechia' 'Türkiye' 'Poland' 'Macao SAR, China'
#  'Iran (Islamic Republic of)' 'Jordan' 'Oman' 'Peru' 'Egypt' 'Pakistan'
#  'Greece' 'Estonia' 'Philippines' 'Brunei Darussalam' 'Luxembourg'
#  'Lithuania' 'Belarus' 'Cyprus' 'Uzbekistan' 'Viet Nam' 'Costa Rica'
#  'Slovenia' 'Kuwait' 'Hungary' 'Iceland' 'Bangladesh' 'Bahrain' 'Uruguay'
#  'Slovakia' 'Azerbaijan' 'Northern Cyprus' 'Croatia' 'Ukraine' 'Bulgaria'
# ...

# %%
df.dtypes
# Out:
# Country/Territory     object
# Region                object
# Research              object
# AR SCORE             float64
# ER SCORE             float64
# CPF SCORE            float64
# EO SCORE             float64
# dtype: object

# %%
df.rename(columns={
    "Country/Territory": "Country",
    "AR SCORE": "Academic_Reputation",
    "ER SCORE": "Employer_Reputation",
    "CPF SCORE": "Research_Quality",    #citations per faculty: measures research quality and output
    "EO SCORE": "Employment_Outcomes"
}, inplace=True)

# %%
df
# Out:
#                        Country    Region Research  Academic_Reputation  \
# 0     United States of America  Americas       VH                100.0
# 1               United Kingdom    Europe       VH                 99.6
# 2     United States of America  Americas       VH                100.0
# 3               United Kingdom    Europe       VH                100.0
# 4     United States of America  Americas       VH                100.0
# ...                        ...       ...      ...                  ...
# 1496                   Czechia    Europe       VH                  7.2
# 1497        Russian Federation    Europe       HI                  5.7
# 1498                  Thailand      Asia       MD                  8.3
# 1499                     Japan      Asia       HI                  4.4
# 1500         Republic of Korea      Asia       MD                  6.5
#
#       Employer_Reputation  Research_Quality  Employment_Outcomes
# ...

# %%
# df.to_csv("qs_clean.csv", index=False)
